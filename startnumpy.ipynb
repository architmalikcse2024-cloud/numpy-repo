# %%
print("hello")
# Out:
# hello

# %%
print("hello how are you")
# Out:
# hello how are you

# %%
def hello():
    print("hello how are you")

# %%
hello()
# Out:
# hello how are you

# %%
def addition(a,b):
    print(a+b)

# %%
addition(2,5)
# Out:
# 7

# %%
 ### only same datatype ###
